# %% [markdown]
# <a href="https://colab.research.google.com/github/budennovsk/Pandas/blob/master/ols_sku_v3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df_org = pd.read_excel('/content/mat_y_40_sku.xlsx')

# %%
# df['Date'] = pd.to_datetime(df[['Year', 'Month']].assign(Day=1)).dt.to_period('M')
df_org
# Out:
#       Month  Year                                           Sku_name  \
# 0         1  2022        Сыр полутвёрдый BELFOR Флоу-пак 240 г 45,0%
# 1         2  2022        Сыр полутвёрдый BELFOR Флоу-пак 240 г 45,0%
# 2         3  2022        Сыр полутвёрдый BELFOR Флоу-пак 240 г 45,0%
# 3         1  2024  Сыр полутвёрдый Casa Margot Эмменталер Флоу-па...
# 4         2  2024  Сыр полутвёрдый Casa Margot Эмменталер Флоу-па...
# ...     ...   ...                                                ...
# 2030     10  2023  Сыр полутвёрдый Эконива Щучанский Флоу-пак 200...
# 2031     11  2022  Сыр полутвёрдый Эконива Щучанский Флоу-пак 200...
# 2032     11  2023  Сыр полутвёрдый Эконива Щучанский Флоу-пак 200...
# 2033     12  2022  Сыр полутвёрдый Эконива Щучанский Флоу-пак 200...
# 2034     12  2023  Сыр полутвёрдый Эконива Щучанский Флоу-пак 200...
#
#      Analytic1      Articul8        Brand  PRICE_PER_UNIT  SALES_VOL  \
# 0        240 г       Другой3       BELFOR      757.015534      68.88
# 1        240 г       Другой3       BELFOR      767.246528       2.88
# 2        240 г       Другой3       BELFOR      999.458333       0.24
# 3        150 г    Эмменталер  Casa Margot     3024.421769      14.70
# 4        150 г    Эмменталер  Casa Margot     3118.870635      12.60
# ...        ...           ...          ...             ...        ...
# 2030     200 г  Классический      Эконива      685.842388   14049.80
# 2031     200 г  Классический      Эконива      851.198597    3244.00
# 2032     200 г  Классический      Эконива      702.743684   12592.60
# 2033     200 г  Классический      Эконива      800.631289    8167.40
# 2034     200 г  Классический      Эконива      731.923076   13212.60
#
#       SHARE_VOL_PROMO  SHARE_VOL
# 0            0.971298   0.287575
# 1            0.491319   0.015748
# 2            0.000000   0.002016
# 3            0.777143   1.000000
# 4            0.726190   1.000000
# ...               ...        ...
# 2030         0.712729   0.027145
# 2031         0.410310   0.006087
# 2032         0.418561   0.026897
# 2033         0.680883   0.017582
# 2034         0.065977   0.025346
#
# [2035 rows x 10 columns]

# %%
df_org_top_25 = df_org.groupby(['Sku_name'])['SALES_VOL'].sum()
sku_top_25=df_org_top_25.sort_values(ascending=False).head(25)
df_r = df_org['Sku_name'].apply(lambda x: x in sku_top_25.index.values)
df_org = df_org[df_r].copy()
df_org
# Out:
#       Month  Year                                           Sku_name  \
# 40        1  2022  Сыр полутвёрдый Cheese House Гауда Флоу-пак 18...
# 41        1  2023  Сыр полутвёрдый Cheese House Гауда Флоу-пак 18...
# 42        1  2024  Сыр полутвёрдый Cheese House Гауда Флоу-пак 18...
# 43        2  2022  Сыр полутвёрдый Cheese House Гауда Флоу-пак 18...
# 44        2  2023  Сыр полутвёрдый Cheese House Гауда Флоу-пак 18...
# ...     ...   ...                                                ...
# 2030     10  2023  Сыр полутвёрдый Эконива Щучанский Флоу-пак 200...
# 2031     11  2022  Сыр полутвёрдый Эконива Щучанский Флоу-пак 200...
# 2032     11  2023  Сыр полутвёрдый Эконива Щучанский Флоу-пак 200...
# 2033     12  2022  Сыр полутвёрдый Эконива Щучанский Флоу-пак 200...
# 2034     12  2023  Сыр полутвёрдый Эконива Щучанский Флоу-пак 200...
#
#      Analytic1      Articul8         Brand  PRICE_PER_UNIT  SALES_VOL  \
# 40       180 г         Гауда  Cheese House      733.371208     203.04
# 41       180 г         Гауда  Cheese House      617.530714    4963.50
# 42       180 г         Гауда  Cheese House      630.556730    7907.04
# 43       180 г         Гауда  Cheese House      621.556729     247.14
# 44       180 г         Гауда  Cheese House      624.786691    4839.12
# ...        ...           ...           ...             ...        ...
# 2030     200 г  Классический       Эконива      685.842388   14049.80
# 2031     200 г  Классический       Эконива      851.198597    3244.00
# 2032     200 г  Классический       Эконива      702.743684   12592.60
# 2033     200 г  Классический       Эконива      800.631289    8167.40
# 2034     200 г  Классический       Эконива      731.923076   13212.60
#
#       SHARE_VOL_PROMO  SHARE_VOL
# 40           0.352261   0.023232
# 41           0.733761   0.658162
# 42           0.720103   0.433913
# 43           0.659994   0.015965
# 44           0.719032   0.774621
# ...               ...        ...
# 2030         0.712729   0.027145
# 2031         0.410310   0.006087
# 2032         0.418561   0.026897
# 2033         0.680883   0.017582
# 2034         0.065977   0.025346
#
# [679 rows x 10 columns]

# %%
# Шаг 1: Импорт необходимых библиотек
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
import seaborn as sns

# Устанавливаем стиль графиков
sns.set(style='darkgrid')
df = df_org.copy()
# Дополнительные данные, которые можно добавить на основе исходного кода
df['Package_Weight'] = df['Analytic1'].str.extract('(\d+)').astype(float)  # Извлечение веса упаковки из столбца Analytic1

brand_list = df['Brand'].unique().tolist()

# Присваиваем ASC значение каждому бренду
asc_values = {brand: idx for idx, brand in enumerate(brand_list)}
df['ASC'] = df['Brand'].map(asc_values)

# Шаг 3: Генерация необходимых переменных для модели

# Кодируем категориальные переменные (Cheese_Type и Brand)
df['Cheese_Type'] = df['Articul8']  # Используем 'Articul8' как тип сыра
df = pd.get_dummies(df, columns=['Cheese_Type', 'Brand'], drop_first=True)
# Преобразование bool переменных в int (0 или 1)
for col in df.columns:
    if df[col].dtype == bool:
        df[col] = df[col].astype(int)

# Определяем независимые переменные
X_columns = [
    'PRICE_PER_UNIT', 'SALES_VOL', 'SHARE_VOL_PROMO', 'Package_Weight', 'ASC'
] + [col for col in df.columns if col.startswith('Cheese_Type_') or col.startswith('Brand_')]

# Зависимая переменная
df['market_share'] = df.groupby(['Year', 'Month'])['SALES_VOL'].transform(lambda x: x / x.sum())

# Логарифм отношения долей рынка
df['base_market_share'] = df.groupby(['Year', 'Month'])['market_share'].transform('first')
df['log_share_ratio'] = np.log(df['market_share'] / df['base_market_share'])

# # Удаление строк с NaN значениями
# df.dropna(subset=X_columns + ['log_share_ratio'], inplace=True)

# # Проверка типов данных после преобразования
# print("Типы данных после преобразования:\n", df[X_columns].dtypes)


# Шаг 4: Подготовка данных для модели и оценка

# Разделение на зависимую и независимые переменные
Y = df['log_share_ratio']
X = df[X_columns]

# Добавляем константу
X = sm.add_constant(X)

# Оцениваем модель с помощью OLS (линейная регрессия)
model = sm.OLS(Y, X).fit()

# Выводим результаты модели
print("\nРезультаты оценки модели:")
print(model.summary())

# Сохраним коэффициенты модели
model_coefficients = model.params

# Шаг 5: Прогнозирование долей рынка на основе полученных коэффициентов

# Вычисляем теоретическую утилиту (utility) для каждого SKU
df['utility'] = model.predict(X)

# Экспонента утилиты
df['exp_utility'] = np.exp(df['utility'])

# Пересчет прогнозируемых долей рынка
df['pred_market_share'] = df.groupby(['Year', 'Month'])['exp_utility'].transform(lambda x: x / x.sum())

# Выводим средние прогнозируемые доли рынка по SKU
mean_market_shares = df.groupby('Sku_name')['pred_market_share'].mean().reset_index()
# print("\nСредние прогнозируемые доли рынка по SKU:")
# print(mean_market_shares.sort_values('pred_market_share', ascending=False))

# Шаг 6: Исключение SKU и пересчет (анализ чувствительности)

# Удаление определенного SKU (например, 'Сыр полутвёрдый BELFOR Флоу-пак 240 г 45,0%')
df_after = df[df['Sku_name'] != 'Сыр полутвёрдый Брест Литовск Российский Флоу-пак 200 г 50,0%'].copy()

# Пересчет прогнозируемых долей рынка
df_after['pred_market_share_after'] = df_after.groupby(['Year', 'Month'])['exp_utility'].transform(lambda x: x / x.sum())

# Шаг 7: Анализ и визуализация результатов
comparison = df.merge(df_after[['Year', 'Month', 'Sku_name', 'pred_market_share_after']], on=['Year', 'Month', 'Sku_name'], how='outer', suffixes=('', '_after'))
comparison['pred_market_share_after'] = comparison['pred_market_share_after'].fillna(0)

# Рассчитываем изменение долей рынка
comparison['market_share_change'] = comparison['pred_market_share_after'] - comparison['pred_market_share']

# # Визуализация изменения долей рынка
# plt.figure(figsize=(12, 6))
# for sku in df['Sku_name'].unique():
#     sku_data = comparison[comparison['Sku_name'] == sku]
#     plt.plot(sku_data['Month'], sku_data['market_share_change'], marker='o', label=sku)
# plt.xlabel('Месяц')
# plt.ylabel('Изменение прогнозируемой доли рынка')
# plt.title('Изменение прогнозируемой доли рынка по SKU')
# # plt.legend()
# plt.show()
# Out:
# Результаты оценки модели:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        log_share_ratio   R-squared:                       0.315
# Model:                            OLS   Adj. R-squared:                  0.289
# Method:                 Least Squares   F-statistic:                     12.02
# Date:                Wed, 09 Oct 2024   Prob (F-statistic):           2.90e-39
# Time:                        13:11:56   Log-Likelihood:                -1378.4
# No. Observations:                 679   AIC:                             2809.
# Df Residuals:                     653   BIC:                             2926.
# Df Model:                          25
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# const                           2.9960      1.686      1.777      0.076      -0.314       6.306
# PRICE_PER_UNIT                 -0.0050      0.001     -4.342      0.000      -0.007      -0.003
# SALES_VOL                    2.228e-05   7.25e-06      3.075      0.002    8.05e-06    3.65e-05
# SHARE_VOL_PROMO                 0.0258      0.457      0.056      0.955      -0.872       0.923
# Package_Weight                  0.0010      0.004      0.266      0.790      -0.006       0.008
# ASC                             0.3011      0.133      2.262      0.024       0.040       0.563
# Cheese_Type_Гауда              -0.0820      0.862     -0.095      0.924      -1.774       1.610
# Cheese_Type_Калачеевский       -0.5847      0.760     -0.770      0.442      -2.076       0.907
# Cheese_Type_Классический        0.5385      0.511      1.054      0.292      -0.465       1.542
# Cheese_Type_Колыбельский        0.5627      0.686      0.820      0.412      -0.784       1.910
# Cheese_Type_Купеческий         -0.8799      0.510     -1.724      0.085      -1.882       0.122
# Cheese_Type_Легкий             -0.7837      0.689     -1.138      0.256      -2.137       0.569
# Cheese_Type_Львиное сердце     -0.8657      0.312     -2.778      0.006      -1.477      -0.254
# Cheese_Type_Маасдам             0.5498      0.701      0.784      0.433      -0.827       1.927
# Cheese_Type_Монастырский       -1.5595      0.809     -1.927      0.054      -3.148       0.029
# Cheese_Type_Российский         -0.1191      0.715     -0.166      0.868      -1.524       1.285
# Cheese_Type_Сливочный           0.2163      0.656      0.330      0.742      -1.072       1.505
# Cheese_Type_Тильзитер          -0.0783      0.687     -0.114      0.909      -1.427       1.271
# Cheese_Type_Топленое молоко     0.5812      0.302      1.926      0.055      -0.011       1.174
# Cheese_Type_Финский            -1.7396      0.778     -2.237      0.026      -3.267      -0.213
# Brand_LAPLANDIA                 0.9195      0.830      1.107      0.269      -0.711       2.550
# Brand_Белебеевский              0.4859      0.590      0.823      0.411      -0.673       1.645
# Brand_Богдаша                  -0.6831      0.574     -1.190      0.235      -1.810       0.444
# Brand_Брест Литовск             1.2289      0.432      2.842      0.005       0.380       2.078
# Brand_Вкуснотеево               0.9014      0.336      2.687      0.007       0.243       1.560
# Brand_Ламбер                    1.7247      0.469      3.677      0.000       0.804       2.646
# Brand_Радость вкуса            -0.2845      0.355     -0.801      0.423      -0.982       0.413
# Brand_Эконива                  -2.1651      0.571     -3.791      0.000      -3.287      -1.044
# ==============================================================================
# Omnibus:                       37.483   Durbin-Watson:                   2.454
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              117.995
# Skew:                           0.136   Prob(JB):                     2.39e-26
# Kurtosis:                       5.024   Cond. No.                     1.36e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 3.65e-21. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
# Шанг 1: Исключение конкретного SKU из данных
sku_to_exclude = 'Сыр полутвёрдый Брест Литовск Российский Флоу-пак 200 г 50,0%'

# Пересчет долей рынка ДО исключения SKU
df['exp_utility'] = np.exp(df['utility'])
df['pred_market_share'] = df.groupby(['Year', 'Month'])['exp_utility'].transform(lambda x: x / x.sum())

# Сохранение долей рынка до исключения
market_share_before = df.groupby('Sku_name')['pred_market_share'].sum().reset_index()

# Проверка создания столбца pred_market_share_before
print("Столбцы в 'market_share_before':", market_share_before.columns)

# Переименование столбца для удобства
market_share_before.rename(columns={'pred_market_share': 'pred_market_share_before'}, inplace=True)

# Исключение SKU из данных и пересчет долей рынка
df_after_exclusion = df[df['Sku_name'] != sku_to_exclude].copy()
df_after_exclusion['pred_market_share_after'] = df_after_exclusion.groupby(['Year', 'Month'])['exp_utility'].transform(lambda x: x / x.sum())

# Сохранение долей рынка после исключения
market_share_after = df_after_exclusion.groupby('Sku_name')['pred_market_share_after'].sum().reset_index()

# Проверка создания столбца pred_market_share_after
print("Столбцы в 'market_share_after':", market_share_after.columns)

# Сравнение до и после исключения SKU
comparison = pd.merge(market_share_before, market_share_after, on='Sku_name', how='outer')
print("Столбцы в 'comparison' после объединения:", comparison.columns)

# Заполнение пропущенных значений для исключенного SKU
comparison['pred_market_share_after'] = comparison['pred_market_share_after'].fillna(0)

# Рассчитываем суммарную долю рынка по SKU
total_market_share_before = comparison['pred_market_share_before'].sum()
total_market_share_after = comparison['pred_market_share_after'].sum()

# Нормализация долей рынка для круговых диаграмм
comparison['pred_market_share_before'] = comparison['pred_market_share_before'] / total_market_share_before
comparison['pred_market_share_after'] = comparison['pred_market_share_after'] / total_market_share_after

# Шаг 2: Построение круговых диаграмм до и после исключения SKU

fig, axes = plt.subplots(1, 2, figsize=(14, 7))

# Круговая диаграмма долей рынка до исключения SKU
axes[0].pie(comparison['pred_market_share_before'], labels=comparison['Sku_name'], autopct='%1.1f%%', startangle=140)
axes[0].set_title('Прогнозируемые доли рынка (до исключения SKU)')

# Круговая диаграмма долей рынка после исключения SKU
axes[1].pie(comparison['pred_market_share_after'], labels=comparison['Sku_name'], autopct='%1.1f%%', startangle=140)
axes[1].set_title('Прогнозируемые доли рынка (после исключения SKU)')

plt.suptitle(f'Сравнение долей рынка до и после исключения "{sku_to_exclude}"')
plt.show()

# Печать изменений в долях рынка
print("\nИзменения долей рынка после исключения SKU:")
print(comparison.sort_values('pred_market_share_after', ascending=False).to_string())
# Out:
# Столбцы в 'market_share_before': Index(['Sku_name', 'pred_market_share'], dtype='object')
# Столбцы в 'market_share_after': Index(['Sku_name', 'pred_market_share_after'], dtype='object')
# Столбцы в 'comparison' после объединения: Index(['Sku_name', 'pred_market_share_before', 'pred_market_share_after'], dtype='object')
# Изменения долей рынка после исключения SKU:
#                                                                 Sku_name  pred_market_share_before  pred_market_share_after
# 6        Сыр полутвёрдый Брест Литовск Классический Флоу-пак 200 г 45,0%                  0.194497                 0.224402
# 11          Сыр полутвёрдый Брест Литовск Сливочный Флоу-пак 200 г 50,0%                  0.107282                 0.128249
# 17                           Сыр полутвёрдый Ламбер Флоу-пак 230 г 50,0%                  0.077426                 0.092236
# 16            Сыр полутвёрдый Вкуснотеево Сливочный Флоу-пак 200 г 45,0%                  0.066521                 0.079301
# 9        Сыр полутвёрдый Брест Литовск Монастырский Флоу-пак 200 г 45,0%                  0.065278                 0.077639
# 15    Сыр полутвёрдый Вкуснотеево Премиум Тильзитер Флоу-пак 200 г 45,0%                  0.063780                 0.076073
# 8             Сыр полутвёрдый Брест Литовск Маасдам Флоу-пак 200 г 45,0%                  0.051019                 0.060819
# 19    Сыр полутвёрдый Радость вкуса Топленое молоко Флоу-пак 200 г 45,0%                  0.041621                 0.049877
# 13         Сыр полутвёрдый Вкуснотеево Калачеевский Флоу-пак 200 г 45,0%                  0.023878                 0.028457
# 7              Сыр полутвёрдый Брест Литовск Легкий Флоу-пак 200 г 35,0%                  0.021681                 0.026567
# 4                      Сыр полутвёрдый Белебеевский Флоу-пак 190 г 45,0%                  0.021747                 0.025842
# 14     Сыр полутвёрдый Вкуснотеево Легкий Сливочный Флоу-пак 200 г 30,0%                  0.017605                 0.020830
# 21             Сыр полутвёрдый Эконива Колыбельский Флоу-пак 200 г 45,0%                  0.016214                 0.019355
# 24                Сыр полутвёрдый Эконива Щучанский Флоу-пак 200 г 50,0%                  0.015216                 0.018181
# 0                Сыр полутвёрдый Cheese House Гауда Флоу-пак 180 г 20,0%                  0.008160                 0.009768
# 5                 Сыр полутвёрдый Богдаша Сливочный Флоу-пак 200 г 45,0%                  0.007373                 0.008874
# 12            Сыр полутвёрдый Брест Литовск Финский Флоу-пак 200 г 45,0%                  0.007424                 0.008768
# 2   Сыр полутвёрдый Белебеевский Башкирский медовый Флоу-пак 190 г 50,0%                  0.007199                 0.008532
# 1        Сыр полутвёрдый LAPLANDIA Сливочный б/лакт Флоу-пак 200 г 45,0%                  0.007047                 0.008333
# 18     Сыр полутвёрдый Радость вкуса Львиное сердце Флоу-пак 200 г 45,0%                  0.006238                 0.007435
# 22                Сыр полутвёрдый Эконива Тильзитер Флоу-пак 160 г 50,0%                  0.005642                 0.006656
# 20                    Сыр полутвёрдый Эконива Гауда Флоу-пак 160 г 45,0%                  0.005099                 0.006020
# 23                Сыр полутвёрдый Эконива Тильзитер Флоу-пак 400 г 50,0%                  0.003560                 0.004159
# 3           Сыр полутвёрдый Белебеевский Купеческий Флоу-пак 190 г 52,0%                  0.003064                 0.003629
# 10         Сыр полутвёрдый Брест Литовск Российский Флоу-пак 200 г 50,0%                  0.155428                 0.000000

# %%
import matplotlib.pyplot as plt
import numpy as np

# Функция для построения круговой диаграммы с фильтрацией меток по доле рынка
def plot_pie_chart_with_filtered_labels(ax, sizes, labels, title, min_share=0.10):
    # Фильтрация меток, отображаем только те, у которых доля >= min_share
    display_labels = [label if size >= min_share else '' for label, size in zip(labels, sizes)]

    # Построение круговой диаграммы
    wedges, texts, autotexts = ax.pie(sizes, labels=display_labels, autopct=lambda pct: f'{pct:.1f}%' if pct >= min_share * 100 else '',
                                      startangle=140, wedgeprops=dict(width=0.3), textprops=dict(size=10))

    # Расположение меток за пределами диаграммы
    for i, text in enumerate(texts):
        if display_labels[i] != '':  # Только для тех меток, которые нужно отобразить
            angle = (wedges[i].theta2 + wedges[i].theta1) / 2  # Средний угол для метки
            x = np.cos(np.radians(angle))  # x координата
            y = np.sin(np.radians(angle))  # y координата
            text.set_position([1.2 * x, 1.2 * y])  # Установка положения за пределами диаграммы
            text.set_horizontalalignment('center' if -90 < angle < 90 else 'right')

    # Установка заголовка диаграммы
    ax.set_title(title, fontsize=14)
    return ax

# Исключаемый SKU
sku_to_exclude = 'Сыр полутвёрдый Брест Литовск Российский Флоу-пак 200 г 50,0%'

# Пересчет долей рынка ДО исключения SKU
df['exp_utility'] = np.exp(df['utility'])
df['pred_market_share'] = df.groupby(['Year', 'Month'])['exp_utility'].transform(lambda x: x / x.sum())

# Сохранение долей рынка до исключения
market_share_before = df.groupby('Sku_name')['pred_market_share'].sum().reset_index()
market_share_before.rename(columns={'pred_market_share': 'pred_market_share_before'}, inplace=True)

# Исключение SKU из данных и пересчет долей рынка
df_after_exclusion = df[df['Sku_name'] != sku_to_exclude].copy()
df_after_exclusion['pred_market_share_after'] = df_after_exclusion.groupby(['Year', 'Month'])['exp_utility'].transform(lambda x: x / x.sum())

# Сохранение долей рынка после исключения
market_share_after = df_after_exclusion.groupby('Sku_name')['pred_market_share_after'].sum().reset_index()

# Сравнение до и после исключения SKU
comparison = pd.merge(market_share_before, market_share_after, on='Sku_name', how='outer')
comparison['pred_market_share_after'] = comparison['pred_market_share_after'].fillna(0)

# Рассчитываем суммарную долю рынка по SKU
total_market_share_before = comparison['pred_market_share_before'].sum()
total_market_share_after = comparison['pred_market_share_after'].sum()

# Нормализация долей рынка для круговых диаграмм
comparison['pred_market_share_before'] = comparison['pred_market_share_before'] / total_market_share_before
comparison['pred_market_share_after'] = comparison['pred_market_share_after'] / total_market_share_after

# Извлечение данных для диаграмм
sizes_before = comparison['pred_market_share_before'].values
sizes_after = comparison['pred_market_share_after'].values
labels = comparison['Sku_name'].values

# Построение круговых диаграмм
fig, ax = plt.subplots(1, 2, figsize=(18, 9))

# Круговая диаграмма долей рынка до исключения SKU (убираем метки с долей < 10%)
plot_pie_chart_with_filtered_labels(ax[0], sizes_before, labels, 'Прогнозируемые доли рынка (до исключения SKU)', min_share=0.10)

# Круговая диаграмма долей рынка после исключения SKU (убираем метки с долей < 10%)
plot_pie_chart_with_filtered_labels(ax[1], sizes_after, labels, 'Прогнозируемые доли рынка (после исключения SKU)', min_share=0.10)

# Общий заголовок
plt.suptitle(f'Сравнение долей рынка до и после исключения "{sku_to_exclude}"', fontsize=16)
plt.tight_layout()
plt.show()

# Вывод доли рынка для интересующего SKU
specific_sku_share = comparison[comparison['Sku_name'] == sku_to_exclude]
if not specific_sku_share.empty:
    print(f"\nДоля рынка '{sku_to_exclude}' до исключения: {specific_sku_share['pred_market_share_before'].values[0]:.4f}")
    print(f"Доля рынка '{sku_to_exclude}' после исключения: {specific_sku_share['pred_market_share_after'].values[0]:.4f}")
else:
    print(f"\nДоля рынка '{sku_to_exclude}' после исключения: 0 (SKU исключен)")
# Out:
# Доля рынка 'Сыр полутвёрдый Брест Литовск Российский Флоу-пак 200 г 50,0%' до исключения: 0.1554
# Доля рынка 'Сыр полутвёрдый Брест Литовск Российский Флоу-пак 200 г 50,0%' после исключения: 0.0000

# %%
mean_org = pd.DataFrame()
mean_org['org_market_share'] = df_org.groupby('Sku_name')['SHARE_VOL'].mean()
mean_org
# Out:
#                                                     org_market_share
# Sku_name
# Сыр полутвёрдый Cheese House Гауда Флоу-пак 180...          0.457735
# Сыр полутвёрдый LAPLANDIA Сливочный б/лакт Флоу...          0.008063
# Сыр полутвёрдый Белебеевский Башкирский медовый...          0.181993
# Сыр полутвёрдый Белебеевский Купеческий Флоу-па...          0.176310
# Сыр полутвёрдый Белебеевский Флоу-пак 190 г 45,0%           0.553983
# Сыр полутвёрдый Богдаша Сливочный Флоу-пак 200 ...          0.012007
# Сыр полутвёрдый Брест Литовск Классический Флоу...          0.124400
# Сыр полутвёрдый Брест Литовск Легкий Флоу-пак 2...          0.045759
# Сыр полутвёрдый Брест Литовск Маасдам Флоу-пак ...          0.049080
# Сыр полутвёрдый Брест Литовск Монастырский Флоу...          0.185615
# Сыр полутвёрдый Брест Литовск Российский Флоу-п...          0.150726
# Сыр полутвёрдый Брест Литовск Сливочный Флоу-па...          0.113191
# Сыр полутвёрдый Брест Литовск Финский Флоу-пак ...          0.013395
# Сыр полутвёрдый Вкуснотеево Калачеевский Флоу-п...          0.025666
# Сыр полутвёрдый Вкуснотеево Легкий Сливочный Фл...          0.013912
# Сыр полутвёрдый Вкуснотеево Премиум Тильзитер Ф...          0.085812
# Сыр полутвёрдый Вкуснотеево Сливочный Флоу-пак ...          0.064234
# Сыр полутвёрдый Ламбер Флоу-пак 230 г 50,0%                 0.961968
# Сыр полутвёрдый Радость вкуса Львиное сердце Фл...          0.009250
# Сыр полутвёрдый Радость вкуса Топленое молоко Ф...          0.046441
# Сыр полутвёрдый Эконива Гауда Флоу-пак 160 г 45,0%          0.584738
# Сыр полутвёрдый Эконива Колыбельский Флоу-пак 2...          0.023894
# Сыр полутвёрдый Эконива Тильзитер Флоу-пак 160 ...          0.453013
# Сыр полутвёрдый Эконива Тильзитер Флоу-пак 400 ...          0.930579
# Сыр полутвёрдый Эконива Щучанский Флоу-пак 200 ...          0.025880

# %%
mean_market_shares
# Out:
#                                              Sku_name  pred_market_share
# 0   Сыр полутвёрдый Cheese House Гауда Флоу-пак 18...           0.008160
# 1   Сыр полутвёрдый LAPLANDIA Сливочный б/лакт Фло...           0.007047
# 2   Сыр полутвёрдый Белебеевский Башкирский медовы...           0.007199
# 3   Сыр полутвёрдый Белебеевский Купеческий Флоу-п...           0.003536
# 4   Сыр полутвёрдый Белебеевский Флоу-пак 190 г 45,0%           0.021747
# 5   Сыр полутвёрдый Богдаша Сливочный Флоу-пак 200...           0.007373
# 6   Сыр полутвёрдый Брест Литовск Классический Фло...           0.194497
# 7   Сыр полутвёрдый Брест Литовск Легкий Флоу-пак ...           0.021681
# 8   Сыр полутвёрдый Брест Литовск Маасдам Флоу-пак...           0.051019
# 9   Сыр полутвёрдый Брест Литовск Монастырский Фло...           0.085145
# 10  Сыр полутвёрдый Брест Литовск Российский Флоу-...           0.155428
# 11  Сыр полутвёрдый Брест Литовск Сливочный Флоу-п...           0.107282
# 12  Сыр полутвёрдый Брест Литовск Финский Флоу-пак...           0.007424
# 13  Сыр полутвёрдый Вкуснотеево Калачеевский Флоу-...           0.023878
# 14  Сыр полутвёрдый Вкуснотеево Легкий Сливочный Ф...           0.017605
# 15  Сыр полутвёрдый Вкуснотеево Премиум Тильзитер ...           0.063780
# 16  Сыр полутвёрдый Вкуснотеево Сливочный Флоу-пак...           0.066521
# 17        Сыр полутвёрдый Ламбер Флоу-пак 230 г 50,0%           0.077426
# 18  Сыр полутвёрдый Радость вкуса Львиное сердце Ф...           0.006238
# 19  Сыр полутвёрдый Радость вкуса Топленое молоко ...           0.041621
# 20  Сыр полутвёрдый Эконива Гауда Флоу-пак 160 г 4...           0.012748
# 21  Сыр полутвёрдый Эконива Колыбельский Флоу-пак ...           0.016214
# 22  Сыр полутвёрдый Эконива Тильзитер Флоу-пак 160...           0.015387
# 23  Сыр полутвёрдый Эконива Тильзитер Флоу-пак 400...           0.015259
# 24  Сыр полутвёрдый Эконива Щучанский Флоу-пак 200...           0.015216

# %%
# Функция для построения круговой диаграммы с фильтрацией меток по доле рынка
def plot_pie_chart_with_filtered_labels(ax, sizes, labels, title, min_share=0.10):
    # Фильтрация меток, отображаем только те, у которых доля >= min_share
    display_labels = [label if size >= min_share else '' for label, size in zip(labels, sizes)]

    # Построение круговой диаграммы
    wedges, texts, autotexts = ax.pie(sizes, labels=display_labels, autopct=lambda pct: f'{pct:.1f}%' if pct >= min_share * 100 else '',
                                      startangle=140, wedgeprops=dict(width=0.3), textprops=dict(size=10))

    # Установка заголовка диаграммы
    ax.set_title(title, fontsize=14)
    return ax

# Извлечение данных для построения диаграмм
sizes_org = mean_org['org_market_share'].values
sizes_pred = mean_market_shares['pred_market_share'].values
labels_org = mean_org.index.values
labels_pred = mean_market_shares['Sku_name'].values

# Построение круговых диаграмм с фильтрацией меток

fig, ax = plt.subplots(1, 2, figsize=(14, 7))

# Круговая диаграмма на основе SHARE_VOL (new_df) с фильтрацией меток по доле
plot_pie_chart_with_filtered_labels(ax[0], sizes_org, labels_org, 'Доля рынка истина SHARE_VOL', min_share=0.10)

# Круговая диаграмма на основе предсказанной утилиты (market_share_before) с фильтрацией меток по доле
plot_pie_chart_with_filtered_labels(ax[1], sizes_pred, labels_pred, 'Доля рынка на основе Модельная(расчетная)', min_share=0.10)

# Общий заголовок
plt.suptitle('Сравнение долей рынка (Фильтрация меток < 10%)', fontsize=16)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-80-eb677e837f6f>:32: UserWarning: Tight layout not applied. tight_layout cannot make axes width small enough to accommodate all axes decorations
#   plt.tight_layout()

# %%
# mean_market_shares
# mean_org

# market_share_before,new_df
from sklearn.metrics import mean_absolute_error, r2_score
# Расчет MAE
mae = mean_absolute_error(mean_org['org_market_share'].values,mean_market_shares['pred_market_share'].values)
print(f'MAE: {mae:.2f}')

# Расчет R²
r2 = r2_score(mean_org['org_market_share'].values,mean_market_shares['pred_market_share'].values)
print(f'R²: {r2:.2f}')

# Расчет WAPE
wape = sum(abs(mean_org['org_market_share'].values - mean_market_shares['pred_market_share'].values) / sum(mean_org['org_market_share'].values))
print(f'WAPE: {wape:.2f}')
# Out:
# MAE: 0.18
# R²: -0.42
# WAPE: 0.83
