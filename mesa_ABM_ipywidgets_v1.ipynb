# %% [markdown]
# <a href="https://colab.research.google.com/github/budennovsk/Pandas/blob/master/mesa_ABM_ipywidgets_v1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install mesa ipywidgets
# Out:
# ...
#   Using cached jedi-0.19.1-py2.py3-none-any.whl.metadata (22 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.6/41.6 kB 1.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.2/69.2 kB 2.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 30.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 35.8 MB/s eta 0:00:00
# ...
# Using cached jedi-0.19.1-py2.py3-none-any.whl (1.6 MB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.5/133.5 kB 7.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.4/66.4 kB 3.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 34.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.1/6.1 MB 46.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.9/107.9 kB 7.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.1/73.1 kB 4.7 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
df = pd.read_excel('/content/mat_y_40_sku.xlsx')

# %%
df['Analytic1_encoded'] = df['Analytic1'].astype('category').cat.codes
df_12=df[(df['Month']==12) & (df['Analytic4']=='Ванночки')].copy()
df_12['share_vol'] =df['SALES VOL'].apply(lambda x: x/(df_12['SALES VOL'].sum()))
df_12
# Out:
#      Month  Year  PRICE PER UNIT  SALES VOL  SHARE VOL Analytic4 Analytic1  \
# 23      12  2023      469.424564   76620.40   0.244997  Ванночки     400 г
# 47      12  2023      580.349508   43662.40   0.139612  Ванночки     400 г
# 59      12  2023      449.267694   41569.20   0.132919  Ванночки     400 г
# 83      12  2023      816.116336   31459.00   0.243361  Ванночки     200 г
# 107     12  2023      720.726262   34252.00   0.264967  Ванночки     200 г
# 119     12  2023      581.037628   32166.00   0.102852  Ванночки     400 г
# 131     12  2023      734.084212   23344.80   0.180591  Ванночки     200 г
# 143     12  2023      480.710229   23195.20   0.074168  Ванночки     400 г
# 179     12  2023      306.674636   24783.12   0.758084  Ванночки     180 г
# 215     12  2023      710.796331   18868.40   0.145962  Ванночки     200 г
# 227     12  2023      665.564599   15501.20   0.049566  Ванночки     400 г
# ...

# %%
df_12['SALES VOL'].sum()
# Out:
# 447390.5200000003

# %%
df_12.shape
# Out:
# (18, 11)

# %%
import pandas as pd
from mesa import Agent, Model
from mesa.time import RandomActivation
from mesa.space import MultiGrid
import random

# Агент-потребитель
class ConsumerAgent(Agent):
    def __init__(self, unique_id, model, price_sensitivity, analytic_preference):
        super().__init__(unique_id, model)
        self.price_sensitivity = price_sensitivity
        # self.popularity_sensitivity = popularity_sensitivity
        self.analytic_preference = analytic_preference
        self.choices = []

    def step(self):
        best_product = None
        best_score = -float('inf')

        # Проходим по каждому продукту в модели
        for idx, product in self.model.products.iterrows():
            # Расчет оценки цены
            price_score = -abs(self.price_sensitivity -product['PRICE PER UNIT'])#-product['PRICE PER UNIT'] * self.price_sensitivity

            # Оценка популярности (объем продаж)
            # sales_score = (product['SALES VOL'] / self.model.max_sales_vol) * self.popularity_sensitivity

            # Оценка аналитического параметра
            analytic_score = -abs(self.analytic_preference-product['Analytic1_encoded'])

            # Общая оценка продукта
            total_score = price_score + analytic_score

            if total_score > best_score:
                best_score = total_score
                best_product = idx
              # Сохраняем информацию о текущем продукте
            self.choices.append({
                'product_id': idx,
                'price_score': price_score,
                'analytic_score': analytic_score,
                'total_score': total_score
            })

        # Если агент выбрал продукт, увеличиваем его долю на рынке
        if best_product is not None:
            self.model.products.at[best_product, 'SHARE VOL'] += 1

        # Сохраняем информацию о выбранном продукте
        self.choices[-1]['chosen'] = True if best_product is not None else False
        # print(self.choices)
        # for choice in self.choices:
        #   print(f" chose product {choice['product_id']} with:")
        #   print(f"  Price Score: {choice['price_score']}")
        #   print(f"  Analytic Score: {choice['analytic_score']}")
        #   print(f"  Total Score: {choice['total_score']}")





# Модель рынка
class MarketModel(Model):
    def __init__(self, N, width, height, product_data):
        super().__init__()
        self.num_agents = N  # Количество потребителей
        self.grid = MultiGrid(width, height, True)
        self.schedule = RandomActivation(self)

        # Продукты (SKU) представлены как DataFrame
        self.products = product_data.copy()
        self.products['SHARE VOL'] = 0  # Инициализация доли рынка
        # self.max_sales_vol = self.products['SALES VOL'].max()

        # Создаем агентов-потребителей
        for i in range(self.num_agents):
            price_sensitivity = random.uniform(300, 800)#best_params[0]#   -1.0933  #random.uniform(0.5, 1.5)
            # popularity_sensitivity = best_params[1]*random.uniform(0.1, 10.0) #1.4316 #random.uniform(0.1, 1.0)
            analytic_preference =  random.choice([3, 4, 6])#best_params[1]  #3.8933 #random.uniform(0, 1)  # Предпочтение по параметру Analytic1_encoded
            consumer = ConsumerAgent(i, self, price_sensitivity, analytic_preference)
            self.schedule.add(consumer)

    def step(self):
        # Выполняем один шаг моделирования
        self.products['SHARE VOL'] = 0  # Сбрасываем долю рынка для каждого SKU
        self.schedule.step()

        # Меняем цены продуктов для имитации рыночных изменений
        self.products['PRICE PER UNIT'] *= self.products['PRICE PER UNIT'].apply(lambda x: random.uniform(0.95, 1.05))

        # Динамическое удаление продуктов
        if random.random() < 0.3:  # С вероятностью 30% удаляем продукт
            if not self.products.empty:
                del_sku = random.randint(0, len(self.products) - 1)
                print('Удалили', self.products.iloc[del_sku]['Sku_name'])
                self.products = self.products.drop(self.products.index[del_sku])


initial_products_df = df_12.head(18)
market = MarketModel(100, 10, 10, initial_products_df)

# Моделируем 10 временных шагов
for i in range(10):
    print(f"Step {i+1}")
    market.step()

    # Печать долей рынка каждого SKU
    print(market.products[['Sku_name', 'SHARE VOL']].to_string())
    print('количество агентов голосовавших', market.products['SHARE VOL'].sum())
    print('количесво ску',len(market.products['SHARE VOL']))
# Out:
# Step 1
# Удалили Сыр плавленый LiebenDorf с ветчиной Ванночки 400 г 55,0%
#                                                      Sku_name  SHARE VOL
# 23    Сыр плавленый LiebenDorf Сливочный Ванночки 400 г 55,0%          3
# 47         Сыр плавленый Viola Сливочный Ванночки 400 г 50,0%          0
# 59       Сыр плавленый Свежий ряд Янтарь Ванночки 400 г 45,0%          8
# 83                 Сыр плавленый Фетакса Ванночки 200 г 45,0%         10
# 107     Сыр плавленый Hochland Сливочный Ванночки 200 г 55,0%          3
# 119    Сыр плавленый President Сливочный Ванночки 400 г 45,0%          6
# 131        Сыр плавленый Viola Сливочный Ванночки 200 г 50,0%          9
# 179   Сыр плавленый Ежедень Классический Ванночки 180 г 55,0%         12
# 215    Сыр плавленый Hochland с ветчиной Ванночки 200 г 55,0%          4
# 227    Сыр плавленый Hochland с ветчиной Ванночки 400 г 55,0%          4
# 250   Сыр плавленый President с ветчиной Ванночки 400 г 45,0%         10
# ...

# %%
import numpy as np
from scipy.optimize import minimize
import pandas as pd
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

# Пример objective_function, основанной на условиях
def objective_function(params, product_data):
    price_sensitivity, analytic_preference = params

    total_score = 0
    # Проходим по каждому продукту в данных
    for _, product in product_data.iterrows():
        price_score = -product['PRICE PER UNIT'] * price_sensitivity
        # sales_score = (product['SALES VOL'] / max_sales_vol) * popularity_sensitivity
        analytic_score = -abs(product['Analytic1_encoded'] - analytic_preference)

        product_score = price_score  + analytic_score
        total_score += product_score

    # Возвращаем отрицательное значение для минимизации (максимизация score)
    return -total_score

# Функция для вычисления вероятности покупки продукта
def purchase_likelihood(price_sensitivity, analytic_preference, product):
    price_score = -product['PRICE PER UNIT'] * price_sensitivity
    # sales_score = (product['SALES VOL'] / max_sales_vol) * popularity_sensitivity
    analytic_score = -abs(product['Analytic1_encoded'] - analytic_preference)

    total_score = price_score  + analytic_score
    return np.exp(total_score)  # Экспоненциальная функция для нормализации вероятности

# Оптимизация параметров для калибровки модели на исторических данных
def calibration_objective_function(params, data):
    price_sensitivity, analytic_preference = params
    simulated_sales = []

    # Симуляция продаж на основе вероятностей покупки
    for _, product in data.iterrows():
        score = purchase_likelihood(price_sensitivity,analytic_preference, product)
        simulated_sales.append(score)

    # Приведение продаж к реальному масштабу
    simulated_sales = [s / sum(simulated_sales) * sum(data['PRICE PER UNIT']) for s in simulated_sales]

    # Вычисление ошибки модели (MSE)
    error = sum((simulated_sales[i] - data['PRICE PER UNIT'].iloc[i]) ** 2 for i in range(len(simulated_sales)))
    return error

# Инициализация DataFrame с продуктами (добавь свой DataFrame 'df')
# df = pd.read_csv('your_data.csv')  # Пример, если данные в csv файле

# Начальные параметры для оптимизации (price_sensitivity, popularity_sensitivity, analytic_preference)
initial_params = [0, 0]

# Определение максимального объема продаж
# max_sales_vol = df['SALES VOL'].max()

# Оптимизация параметров модели с вычислением ошибки
result = minimize(calibration_objective_function, initial_params,df,method='Nelder-Mead')

# Получение лучших параметров
best_params = result.x
print("Оптимизированные параметры агента:", best_params)

# Вывод финальной ошибки модели
final_error = calibration_objective_function(best_params, df)
print("Финальная ошибка модели:", final_error)
# Out:
# Оптимизированные параметры агента: [-0.00063304  0.58277643]
# Финальная ошибка модели: 230510028.93185112

# %%
import random

# Случайное число от 300 до 600
random_value = random.randint(300, 600)

print(random_value)
# Out:
# 302

# %%
import random

# Случайный выбор из списка [4, 5, 6]
random_value = random.choice([4, 5, 6])

print(random_value)
# Out:
# 5
