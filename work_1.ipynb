# %% [markdown]
# <a href="https://colab.research.google.com/github/budennovsk/Pandas/blob/master/work_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
[[['X5', 'Пленка', 'Сыр полутвёрдый', 'Дискаунтер', 'Приволжский федеральный округ', 'Сыр полутвёрдый Bonfesto Pizza Моцарелла Пленка 250 г 40,0%', 80.5], ['X5', 'Пленка', 'Сыр полутвёрдый', 'Дискаунтер', 'Приволжский федеральный округ', 'Сыр полутвёрдый Hochland Grunlander Пленка 400 г 50,0%', 1729.6]]
[['X5', 'Пленка', 'Сыр полутвёрдый', 'Дискаунтер', 'Приволжский федеральный округ', 'Сыр полутвёрдый Bonfesto Pizza Моцарелла Пленка 250 г 40,0%', 129.0], ['X5', 'Пленка', 'Сыр полутвёрдый', 'Дискаунтер', 'Приволжский федеральный округ', 'Сыр полутвёрдый Hochland Grunlander Пленка 400 г 50,0%', 2212.4]]]

# %%
columns=['retailer', 'analytic4','group_name', 'format_tt','region','SKU','2024-2','2024-1']
data= [['X5', 'Пленка', 'Сыр полутвёрдый', 'Дискаунтер', 'Приволжский федеральный округ', 'Сыр полутвёрдый Bonfesto Pizza Моцарелла Пленка 250 г 40,0%',80.5,129.0],['X5', 'Пленка', 'Сыр полутвёрдый', 'Дискаунтер', 'Приволжский федеральный округ', 'Сыр полутвёрдый Hochland Grunlander Пленка 400 г 50,0%', 1729.6,2212.4]]

# %%
for i in [[['X5', 'Пленка', 'Сыр полутвёрдый', 'Дискаунтер', 'Приволжский федеральный округ', 'Сыр полутвёрдый Bonfesto Pizza Моцарелла Пленка 250 г 40,0%', 80.5,'2024-02'], ['X5', 'Пленка', 'Сыр полутвёрдый', 'Дискаунтер', 'Приволжский федеральный округ', 'Сыр полутвёрдый Hochland Grunlander Пленка 400 г 50,0%', 1729.6,'2024-02']],
[['X5', 'Пленка', 'Сыр полутвёрдый', 'Дискаунтер', 'Приволжский федеральный округ', 'Сыр полутвёрдый Bonfesto Pizza Моцарелла Пленка 250 г 40,0%', 129.0,'2024-01'], ['X5', 'Пленка', 'Сыр полутвёрдый', 'Дискаунтер', 'Приволжский федеральный округ', 'Сыр полутвёрдый Hochland Grunlander Пленка 400 г 50,0%', 2212.4,'2024-01']]]:
# Out:
# [['X5', 'Пленка', 'Сыр полутвёрдый', 'Дискаунтер', 'Приволжский федеральный округ', 'Сыр полутвёрдый Bonfesto Pizza Моцарелла Пленка 250 г 40,0%', 80.5], ['X5', 'Пленка', 'Сыр полутвёрдый', 'Дискаунтер', 'Приволжский федеральный округ', 'Сыр полутвёрдый Hochland Grunlander Пленка 400 г 50,0%', 1729.6]]
# [['X5', 'Пленка', 'Сыр полутвёрдый', 'Дискаунтер', 'Приволжский федеральный округ', 'Сыр полутвёрдый Bonfesto Pizza Моцарелла Пленка 250 г 40,0%', 129.0], ['X5', 'Пленка', 'Сыр полутвёрдый', 'Дискаунтер', 'Приволжский федеральный округ', 'Сыр полутвёрдый Hochland Grunlander Пленка 400 г 50,0%', 2212.4]]

# %%
import pandas as pd

# Данные для перебора
data = [
    [
        ['X5', 'Пленка', 'Сыр полутвёрдый', 'Дискаунтер', 'Приволжский федеральный округ', 'Сыр полутвёрдый Bonfesto Pizza Моцарелла Пленка 250 г 40,0%', 80.5],
        ['X5', 'Пленка', 'Сыр полутвёрдый', 'Дискаунтер', 'Приволжский федеральный округ', 'Сыр полутвёрдый Hochland Grunlander Пленка 400 г 50,0%', 1729.6]
    ],
    [
        ['X5', 'Пленка', 'Сыр полутвёрдый', 'Дискаунтер', 'Приволжский федеральный округ', 'Сыр полутвёрдый Bonfesto Pizza Моцарелла Пленка 250 г 40,0%', 129.0],
        ['X5', 'Пленка', 'Сыр полутвёрдый', 'Дискаунтер', 'Приволжский федеральный округ', 'Сыр полутвёрдый Hochland Grunlander Пленка 400 г 50,0%', 2212.4]
    ]
]

# Создание словаря для хранения данных
data_dict = {}

# Перебор вложенных списков и заполнение словаря
for idx, period_data in enumerate(data, start=1):
    period_label = f'2024-{idx}'

    for record in period_data:
        key = tuple(record[:6])
        print(key)
        value = record[6]

        if key not in data_dict:
            data_dict[key] = [None] * len(data)
        data_dict[key][idx-1] = value

# Преобразование словаря в список для создания DataFrame
df_data = [list(k) + v for k, v in data_dict.items()]

# Создание DataFrame
columns = ['retailer', 'analytic4', 'group_name', 'format_tt', 'region', 'SKU'] + [f'2024-{i}' for i in range(1, len(data) + 1)]
df = pd.DataFrame(df_data, columns=columns)
df
# Out:
# ('X5', 'Пленка', 'Сыр полутвёрдый', 'Дискаунтер', 'Приволжский федеральный округ', 'Сыр полутвёрдый Bonfesto Pizza Моцарелла Пленка 250 г 40,0%')
# ('X5', 'Пленка', 'Сыр полутвёрдый', 'Дискаунтер', 'Приволжский федеральный округ', 'Сыр полутвёрдый Hochland Grunlander Пленка 400 г 50,0%')
# ('X5', 'Пленка', 'Сыр полутвёрдый', 'Дискаунтер', 'Приволжский федеральный округ', 'Сыр полутвёрдый Bonfesto Pizza Моцарелла Пленка 250 г 40,0%')
# ('X5', 'Пленка', 'Сыр полутвёрдый', 'Дискаунтер', 'Приволжский федеральный округ', 'Сыр полутвёрдый Hochland Grunlander Пленка 400 г 50,0%')
#   retailer analytic4       group_name   format_tt  \
# 0       X5    Пленка  Сыр полутвёрдый  Дискаунтер
# 1       X5    Пленка  Сыр полутвёрдый  Дискаунтер
#
#                           region  \
# 0  Приволжский федеральный округ
# 1  Приволжский федеральный округ
#
#                                                  SKU  2024-1  2024-2
# 0  Сыр полутвёрдый Bonfesto Pizza Моцарелла Пленк...    80.5   129.0
# ...

# %%
import pandas as pd

# Данные для перебора
data = [
    [
        ['X5', 'Пленка', 'Сыр полутвёрдый', 'Дискаунтер', 'Приволжский федеральный округ', 'Сыр полутвёрдый Bonfesto Pizza Моцарелла Пленка 250 г 40,0%', 80.5, '2024-02'],
        ['X5', 'Пленка', 'Сыр полутвёрдый', 'Дискаунтер', 'Приволжский федеральный округ', 'Сыр полутвёрдый Hochland Grunlander Пленка 400 г 50,0%', 1729.6, '2024-02']
    ],
    [
        ['X5', 'Пленка', 'Сыр полутвёрдый', 'Дискаунтер', 'Приволжский федеральный округ', 'Сыр полутвёрдый Bonfesto Pizza Моцарелла Пленка 250 г 40,0%', 129.0, '2024-01'],
        ['X5', 'Пленка', 'Сыр полутвёрдый', 'Дискаунтер', 'Приволжский федеральный округ', 'Сыр полутвёрдый Hochland Grunlander Пленка 400 г 50,0%', 2212.4, '2024-01']
    ]
]

# Создание словаря для хранения данных
data_dict = {}

# Перебор вложенных списков и заполнение словаря
for period_data in data:
    for record in period_data:
        key = tuple(record[:6])
        value = record[6]
        period = record[7]

        if key not in data_dict:
            data_dict[key] = {}
        data_dict[key][period] = value

# Преобразование словаря в список для создания DataFrame
df_data = []
for key, values in data_dict.items():
    row = list(key)
    for period in ['2024-02', '2024-01']:
        row.append(values.get(period, None))
    df_data.append(row)

# Создание DataFrame
columns = ['retailer', 'analytic4', 'group_name', 'format_tt', 'region', 'SKU', '2024-02', '2024-01']
df = pd.DataFrame(df_data, columns=columns)

df
# Out:
#   retailer analytic4       group_name   format_tt  \
# 0       X5    Пленка  Сыр полутвёрдый  Дискаунтер
# 1       X5    Пленка  Сыр полутвёрдый  Дискаунтер
#
#                           region  \
# 0  Приволжский федеральный округ
# 1  Приволжский федеральный округ
#
#                                                  SKU  2024-02  2024-01
# 0  Сыр полутвёрдый Bonfesto Pizza Моцарелла Пленк...     80.5    129.0
# 1  Сыр полутвёрдый Hochland Grunlander Пленка 400...   1729.6   2212.4

# %%
import pandas as pd

# Данные для перебора
data_1 = [
    [
        ['X5', 'Пленка', 'Сыр полутвёрдый', 'Дискаунтер', 'Приволжский федеральный округ', 'Сыр полутвёрдый Bonfesto Pizza Моцарелла Пленка 250 г 40,0%', 80.5, '2024-02'],
        ['X5', 'Пленка', 'Сыр полутвёрдый', 'Дискаунтер', 'Приволжский федеральный округ', 'Сыр полутвёрдый Hochland Grunlander Пленка 400 г 50,0%', 1729.6, '2024-02']
    ],
    [
        ['X5', 'Пленка', 'Сыр полутвёрдый', 'Дискаунтер', 'Приволжский федеральный округ', 'Сыр полутвёрдый Bonfesto Pizza Моцарелла Пленка 250 г 40,0%', 129.0, '2024-01'],
        ['X5', 'Пленка', 'Сыр полутвёрдый', 'Дискаунтер', 'Приволжский федеральный округ', 'Сыр полутвёрдый Hochland Grunlander Пленка 400 г 50,0%', 2212.4, '2024-01']
    ]
]

# Создание списка для хранения всех записей
all_records = []

# Перебор вложенных списков и добавление записей в список
for period_data in data_1:
    for record in period_data:
        all_records.append(record)

# Создание DataFrame
columns = ['retailer', 'analytic4', 'group_name', 'format_tt', 'region', 'SKU', 'SALES_VOL', 'Data_month']
df = pd.DataFrame(all_records, columns=columns)

print(df.to_string())
# Out:
#   retailer analytic4       group_name   format_tt                         region                                                          SKU  SALES_VOL Data_month
# 0       X5    Пленка  Сыр полутвёрдый  Дискаунтер  Приволжский федеральный округ  Сыр полутвёрдый Bonfesto Pizza Моцарелла Пленка 250 г 40,0%       80.5    2024-02
# 1       X5    Пленка  Сыр полутвёрдый  Дискаунтер  Приволжский федеральный округ       Сыр полутвёрдый Hochland Grunlander Пленка 400 г 50,0%     1729.6    2024-02
# 2       X5    Пленка  Сыр полутвёрдый  Дискаунтер  Приволжский федеральный округ  Сыр полутвёрдый Bonfesto Pizza Моцарелла Пленка 250 г 40,0%      129.0    2024-01
# 3       X5    Пленка  Сыр полутвёрдый  Дискаунтер  Приволжский федеральный округ       Сыр полутвёрдый Hochland Grunlander Пленка 400 г 50,0%     2212.4    2024-01

# %%
'retailer','analytic4','group_name','format_tt','region','SKU','SALES_VOL','Data_month'
# Out:
# ('retailer',
#  'analytic4',
#  'group_name',
#  'format_tt',
#  'region',
#  'SKU',
#  'SALES_VOL',
#  'Data_month')

# %%
import pandas as pd

# Ваши данные
all_records = [
    ['X5', 'Пленка', 'Сыр полутвёрдый', 'Дискаунтер', 'Приволжский федеральный округ', 'Сыр полутвёрдый Bonfesto Pizza Моцарелла Пленка 250 г 40,0%', 80.5, '2024-02'],
    ['X5', 'Пленка', 'Сыр полутвёрдый', 'Дискаунтер', 'Приволжский федеральный округ', 'Сыр полутвёрдый Hochland Grunlander Пленка 400 г 50,0%', 1729.6, '2024-02'],
    ['X5', 'Пленка', 'Сыр полутвёрдый', 'Дискаунтер', 'Приволжский федеральный округ', 'Сыр полутвёрдый Bonfesto Pizza Моцарелла Пленка 250 г 40,0%', 129.0, '2024-01'],
    ['X5', 'Пленка', 'Сыр полутвёрдый', 'Дискаунтер', 'Приволжский федеральный округ', 'Сыр полутвёрдый Hochland Grunlander Пленка 400 г 50,0%', 2212.4, '2024-01']
]

# Создание DataFrame
columns = ['retailer', 'analytic4', 'group_name', 'format_tt', 'region', 'SKU', 'SALES_VOL', 'Data_month']
df = pd.DataFrame(all_records, columns=columns)
df['Data_month'] = pd.to_datetime(df['Data_month'])
# Создание сводной таблицы
pivot_df = df.pivot_table(index=['retailer', 'analytic4', 'group_name', 'format_tt', 'region', 'SKU'],
                          columns='Data_month', values='SALES_VOL').reset_index()


# Переименование колонок
pivot_df.columns.name = None
pivot_df.columns = ['retailer', 'analytic4', 'group_name', 'format_tt', 'region', 'SKU']+ df['Data_month'].unique().tolist()
# pivot_df.columns = ['retailer', 'analytic4', 'group_name', 'format_tt', 'region', 'SKU']+sorted(df['Data_month'].unique().tolist(),
#                               key=lambda date: (int(date.split('-')[0]), int(date.split('-')[1])))

print(pivot_df.to_string())
# Out:
#   retailer analytic4       group_name   format_tt                         region                                                          SKU  2024-02-01 00:00:00  2024-01-01 00:00:00
# 0       X5    Пленка  Сыр полутвёрдый  Дискаунтер  Приволжский федеральный округ  Сыр полутвёрдый Bonfesto Pizza Моцарелла Пленка 250 г 40,0%                129.0                 80.5
# 1       X5    Пленка  Сыр полутвёрдый  Дискаунтер  Приволжский федеральный округ       Сыр полутвёрдый Hochland Grunlander Пленка 400 г 50,0%               2212.4               1729.6

# %%
df['Data_month'].unique().tolist()
# Out:
# ['2024-02', '2024-01']

# %%
df['Data_month']
# Out:
# 0   2024-02-01
# 1   2024-02-01
# 2   2024-01-01
# 3   2024-01-01
# Name: Data_month, dtype: datetime64[ns]

# %%
sorted(df['Data_month'].unique().tolist(),
                              key=lambda date: (int(date.split('-')[0]), int(date.split('-')[1])))
# Out:
# ['2024-01', '2024-02']

# %%
import pandas as pd

# Создаем пример DataFrame
data = {'retailer': ['X5', 'X5', 'X5', 'X5', 'X5', 'X5'],
        'analytic4': ['one', 'one', 'two', 'two', 'three', 'three'],
        'group_name': ['foo', 'foo', 'foo', 'foo', 'bar', 'bar'],
        'format_tt': ['small', 'large', 'large', 'small', 'small', 'large'],
        'region': ['North', 'North', 'North', 'South', 'South', 'South'],
        'SKU': ['A', 'B', 'C', 'D', 'E', 'F'],
        'Data_month': ['2024-1', '2024-2', '2024-3', '2024-4', '2024-5', '2024-6'],
        'SALES_VOL': [10, 20, 30, 40, 50, 60]}
df = pd.DataFrame(data)

# Преобразуем столбец Data_month в формат datetime
df['Data_month'] = pd.to_datetime(df['Data_month'])

# Создаем таблицу сводки
pivot_df = pd.pivot_table(df, values='SALES_VOL', index=['retailer', 'analytic4', 'group_name', 'format_tt', 'region', 'SKU'], columns='Data_month').reset_index()

print(pivot_df)
# Out:
# Data_month retailer analytic4 group_name format_tt region SKU  \
# 0                X5       one        foo     large  North   B
# 1                X5       one        foo     small  North   A
# 2                X5     three        bar     large  South   F
# 3                X5     three        bar     small  South   E
# 4                X5       two        foo     large  North   C
# 5                X5       two        foo     small  South   D
#
# Data_month  2024-01-01 00:00:00  2024-02-01 00:00:00  2024-03-01 00:00:00  \
# 0                           NaN                 20.0                  NaN
# 1                          10.0                  NaN                  NaN
# 2                           NaN                  NaN                  NaN
# 3                           NaN                  NaN                  NaN
# 4                           NaN                  NaN                 30.0
# 5                           NaN                  NaN                  NaN
#
# ...

# %%
import pandas as pd

data = {
    'SKU': ['Сыр полутвёрдый Bonfesto Pizza Моцарелла Пленка 250 г 40,0%',
            'Сыр полутвёрдый Hochland Grunlander Пленка 400 г 50,0%',
            'Сыр полутвёрдый LiebenDorf Гауда Пленка 1000 г 45,0%',
            'Сыр полутвёрдый LiebenDorf Маасдам Пленка 1000 г 45,0%',
            'Сыр полутвёрдый LiebenDorf Тильзитер Пленка 1000 г 45,0%'],
    '2023-12-01 00:00:00': [101.75, None, 42943.216, 55588.469, 62122.559],
    '2024-01-01 00:00:00': [129, 1729.6, 44166.604, 41133.619, 48942.212],
    '2024-02-01 00:00:00': [80.5, None, None, None, 43614.367]
}

df = pd.DataFrame(data)
df
# Out:
#                                                  SKU  2023-12-01 00:00:00  \
# 0  Сыр полутвёрдый Bonfesto Pizza Моцарелла Пленк...              101.750
# 1  Сыр полутвёрдый Hochland Grunlander Пленка 400...                  NaN
# 2  Сыр полутвёрдый LiebenDorf Гауда Пленка 1000 г...            42943.216
# 3  Сыр полутвёрдый LiebenDorf Маасдам Пленка 1000...            55588.469
# 4  Сыр полутвёрдый LiebenDorf Тильзитер Пленка 10...            62122.559
#
#    2024-01-01 00:00:00  2024-02-01 00:00:00
# 0              129.000               80.500
# 1             1729.600                  NaN
# 2            44166.604                  NaN
# 3            41133.619                  NaN
# 4            48942.212            43614.367

# %%
df['count'] = df[df.columns.tolist()[1:-1]].count(axis=1)
df
# Out:
#                                                  SKU  2023-12-01 00:00:00  \
# 0  Сыр полутвёрдый Bonfesto Pizza Моцарелла Пленк...              101.750
# 1  Сыр полутвёрдый Hochland Grunlander Пленка 400...                  NaN
# 2  Сыр полутвёрдый LiebenDorf Гауда Пленка 1000 г...            42943.216
# 3  Сыр полутвёрдый LiebenDorf Маасдам Пленка 1000...            55588.469
# 4  Сыр полутвёрдый LiebenDorf Тильзитер Пленка 10...            62122.559
#
#    2024-01-01 00:00:00  2024-02-01 00:00:00  count
# 0              129.000               80.500      3
# 1             1729.600                  NaN      1
# 2            44166.604                  NaN      2
# 3            41133.619                  NaN      2
# 4            48942.212            43614.367      3

# %%
df['summ'] = df[['2024-02-01 00:00:00', '2024-01-01 00:00:00', '2023-12-01 00:00:00']].sum(axis=1)

print(df['summ'])
# Out:
# 0       311.250
# 1      1729.600
# 2     87109.820
# 3     96722.088
# 4    154679.138
# Name: summ, dtype: float64

# %%
import pandas as pd
import numpy as np

# Создание DataFrame
data = {
    'SKU': [
        'Сыр полутвёрдый Bonfesto Pizza Моцарелла Пленка 250 г 40,0%',
        'Сыр полутвёрдый Hochland Grunlander Пленка 400 г 50,0%',
        'Сыр полутвёрдый LiebenDorf Гауда Пленка 1000 г 45,0%',
        'Сыр полутвёрдый LiebenDorf Маасдам Пленка 1000 г 45,0%',
        'Сыр полутвёрдый LiebenDorf Тильзитер Пленка 1000 г 45,0%'
    ],
    '2023-12-01 00:00:00': [101.75, 1729.6, 42943.2159999999, 55588.469, 62122.559],
    '2024-01-01 00:00:00': [129, np.nan, 44166.604, 41133.619, np.nan],
    '2024-02-01 00:00:00': [80.5, np.nan, np.nan, np.nan, 44]
}

df = pd.DataFrame(data)

# Функция для вычисления суммы
def compute_sum(row):
    if pd.isna(row['2024-02-01 00:00:00']):
        return np.nan
    else:
        return row[['2024-01-01 00:00:00', '2024-02-01 00:00:00']].sum(skipna=True)

# Создание новой колонки 'summ'
df['summ'] = df.apply(compute_sum, axis=1)

# Вывод результата
result = df[['summ']]
print(result)
# Out:
#     summ
# 0  209.5
# 1    NaN
# 2    NaN
# 3    NaN
# 4   44.0

# %%
import pandas as pd
df_train = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/zvezda/MIO_1/Dominiks_Cheese_DF/wche.csv')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9427395 entries, 0 to 9427394
# Data columns (total 11 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   STORE       int64
#  1   UPC         int64
#  2   WEEK        int64
#  3   MOVE        int64
#  4   QTY         int64
#  5   PRICE       float64
#  6   SALE        object
#  7   PROFIT      float64
#  8   OK          int64
#  9   PRICE_HEX   object
#  10  PROFIT_HEX  object
# dtypes: float64(2), int64(6), object(3)
# memory usage: 791.2+ MB

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9427395 entries, 0 to 9427394
# Data columns (total 11 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   STORE       int64
#  1   UPC         int64
#  2   WEEK        int64
#  3   MOVE        int64
#  4   QTY         int64
#  5   PRICE       float64
#  6   SALE        object
#  7   PROFIT      float64
#  8   OK          int64
#  9   PRICE_HEX   object
#  10  PROFIT_HEX  object
# dtypes: float64(2), int64(6), object(3)
# memory usage: 791.2+ MB

# %%
df_train
# Out:
#          STORE          UPC  WEEK  MOVE  QTY  PRICE SALE  PROFIT  OK  \
# 0            2   1570077445     1     7    1   2.41  NaN   37.59   1
# 1            2   1570077445     2     8    1   2.41  NaN   37.59   1
# 2            2   1570077445     3     4    1   2.41  NaN   37.14   1
# 3            2   1570077445     4     8    1   2.41  NaN   37.14   1
# 4            2   1570077445     5     7    1   2.41  NaN   37.14   1
# ...        ...          ...   ...   ...  ...    ...  ...     ...  ..
# 9427390    137  73537577002   313     0    1   0.00  NaN    0.00   1
# 9427391    137  73537577002   314     0    1   0.00  NaN    0.00   1
# 9427392    137  73537577002   315     0    1   0.00  NaN    0.00   1
# 9427393    137  73537577002   316     0    1   0.00  NaN    0.00   1
# 9427394    137  73537577002   317     0    1   0.00  NaN    0.00   1
#
#                 PRICE_HEX        PROFIT_HEX
# 0        400347AE147AE148  4042CB851EB851EC
# 1        400347AE147AE148  4042CB851EB851EC
# ...

# %%
! pip install pyspark
! pip install pyarrow
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.0/317.0 MB 1.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pyspark: filename=pyspark-3.5.1-py2.py3-none-any.whl size=317488491 sha256=f7bdfd2bcdcb5ec4e0a62ccb9e47f8bb27ca05839faf36af3ff7e2e2d1636d42
#   Stored in directory: /root/.cache/pip/wheels/80/1d/60/2c256ed38dddce2fdd93be545214a63e02fbd8d74fb0b7f3a6
# Successfully built pyspark
# ...

# %%
from pyspark.sql import SparkSession
import os
spark = SparkSession.builder.getOrCreate()
spark.conf.set("spark.sql.execution.arrow.pyspark.enabled", "true")
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://a2ea2f4efae7:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>pyspark-shell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
df = spark.read.csv('/content/drive/MyDrive/Colab Notebooks/zvezda/MIO_1/Dominiks_Cheese_DF/wche.csv', header=True, inferSchema=True)

df.printSchema()
# Out:
# root
#  |-- STORE: integer (nullable = true)
#  |-- UPC: long (nullable = true)
#  |-- WEEK: integer (nullable = true)
#  |-- MOVE: integer (nullable = true)
#  |-- QTY: integer (nullable = true)
#  |-- PRICE: double (nullable = true)
#  |-- SALE: string (nullable = true)
#  |-- PROFIT: double (nullable = true)
#  |-- OK: integer (nullable = true)
#  |-- PRICE_HEX: string (nullable = true)
#  |-- PROFIT_HEX: string (nullable = true)

# %%
df.show()
# Out:
# +-----+----------+----+----+---+-----+----+------+---+----------------+----------------+
# |STORE|       UPC|WEEK|MOVE|QTY|PRICE|SALE|PROFIT| OK|       PRICE_HEX|      PROFIT_HEX|
# +-----+----------+----+----+---+-----+----+------+---+----------------+----------------+
# |    2|1570077445|   1|   7|  1| 2.41|NULL| 37.59|  1|400347AE147AE148|4042CB851EB851EC|
# |    2|1570077445|   2|   8|  1| 2.41|NULL| 37.59|  1|400347AE147AE148|4042CB851EB851EC|
# |    2|1570077445|   3|   4|  1| 2.41|NULL| 37.14|  1|400347AE147AE148|404291EB851EB852|
# |    2|1570077445|   4|   8|  1| 2.41|NULL| 37.14|  1|400347AE147AE148|404291EB851EB852|
# |    2|1570077445|   5|   7|  1| 2.41|NULL| 37.14|  1|400347AE147AE148|404291EB851EB852|
# |    2|1570077445|   6|   5|  1| 2.41|NULL| 37.39|  1|400347AE147AE148|4042B1EB851EB852|
# |    2|1570077445|   7|  12|  1| 2.41|NULL| 36.85|  1|400347AE147AE148|40426CCCCCCCCCCD|
# ...

# %%
from pyspark.ml.stat import Correlation
from pyspark.ml.feature import VectorAssembler

# %%
# сначала преобразуем данные в объект типа Vector
vector_col = "corr_features"
assembler = VectorAssembler(inputCols=df.columns, outputCol=vector_col)
df_vector = assembler.transform(df).select(vector_col)

# получаем матрицу корреляции и тут же преобразуем данные в numpy вектор
matrix = Correlation.corr(df_vector, vector_col).collect()[0][matrix.columns[0]].toArray() # запаситесь попкорном, данное действие, к сожалению не быстрое
corr_matrix_df = pd.DataFrame(data=matrix, columns = df.columns, index=df.columns) # последний штрих - оборачиваем полученную корреляционную матрицу в pandas DataFrame
# Out:
# ---------------------------------------------------------------------------
# IllegalArgumentException                  Traceback (most recent call last)
# <ipython-input-15-6406707d95a7> in <cell line: 4>()
#       2 vector_col = "corr_features"
#       3 assembler = VectorAssembler(inputCols=df.columns, outputCol=vector_col)
# ----> 4 df_vector = assembler.transform(df).select(vector_col)
#       5
#       6 # получаем матрицу корреляции и тут же преобразуем данные в numpy вектор
#
# /usr/local/lib/python3.10/dist-packages/pyspark/ml/base.py in transform(self, dataset, params)
#     260                 return self.copy(params)._transform(dataset)
#     261             else:
# --> 262                 return self._transform(dataset)
#     263         else:
#     264             raise TypeError("Params must be a param map but got %s." % type(params))
#
# /usr/local/lib/python3.10/dist-packages/pyspark/ml/wrapper.py in _transform(self, dataset)
#     396
# ...
